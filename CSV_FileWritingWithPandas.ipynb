# %%
import pandas as pd

# %%
data = [1,2,3,4,5]

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
DATA = [["SATHISH",10],["SRET",12]]

# %%
data1=[["sathish",10,4.56,],["arjun",45,12.45],["thenu",45,12.6]]

# %%
DF
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-8d962b2673f1> in <module>
# ----> 1 DF
#
# NameError: name 'DF' is not defined

# %%
df= pd.DataFrame(DATA,index=["a","b"],columns=["name","age"])

# %%
df
# Out:
#       name  age
# a  SATHISH   10
# b     SRET   12

# %%
data2 = {"name":["tom","jack","sathish","arjun"],"age":[12,45,19,78]}

# %%
Df = pd.DataFrame(data2,index=["a","b","c","d"])

# %%
Df
# Out:
#       name  age
# a      tom   12
# b     jack   45
# c  sathish   19
# d    arjun   78

# %%
del Df["age"]

# %%
Df
# Out:
#       name
# a      tom
# b     jack
# c  sathish
# d    arjun

# %%
d =Df.drop("b")
d.drop("a")
# Out:
#       name  age
# c  sathish   19
# d    arjun   78

# %%
d
# Out:
#       name  age
# a      tom   12
# c  sathish   19
# d    arjun   78

# %%
df.drop(df.loc[df['age']==10].index, inplace=True)

# %%
df
# Out:
#    name  age
# b  SRET   12

# %%
df1=pd.DataFrame(data1,index=["a","b","c"],columns=["name","age","weight"])

# %%
df1
# Out:
#       name  age  weight
# a  sathish   10    4.56
# b    arjun   45   12.45
# c    thenu   45   12.60

# %%
df1["name"]["b"] = "SathishKumar"
# Out:
# C:\Users\SATHISH\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df1
# Out:
#            name  age  weight
# a       sathish   10    4.56
# b  SathishKumar   45   12.45
# c         thenu   45   12.60

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, a to c
# Data columns (total 3 columns):
# name      3 non-null object
# age       3 non-null int64
# weight    3 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 176.0+ bytes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, b to b
# Data columns (total 2 columns):
# name    1 non-null object
# age     1 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 24.0+ bytes

# %%
df1["name"][4]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 4
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
j = 0
for i in df1["name"]:
    if i == "arjun":
        df1["name"][j]="ABCD"
    j+=1

# %%
df1
# Out:
#            name  age  weight
# a       sathish   10    4.56
# b  SathishKumar   45   12.45
# c         thenu   45   12.60

# %%
df = pd.read_csv("weather.csv")

# %%
df
# Out:
#            Day  Temperature   Wind Speed           Event
# 0   01/01/2018            35         320           Rainy
# 1   02/01/2018            28         123           cloud
# 2   03/01/2018            26         156             Hot
# 3   04/01/2018            29         174  not available
# 4   05/01/2018            30         185           Rainy
# 5   06/01/2018            31         169           cloud
# 6   07/01/2018            32         245             Hot
# 7   08/01/2018            35         123  not available
# 8   09/01/2018            40         156           cloud
# 9   10/01/2018            22         147             Hot
# 10  11/01/2018            35         563  not available
# 11  12/01/2018            28         156           cloud
# 12  13/01/2018            24         412             Hot
# 13  14/01/2018            26         457           Rainy
# 14  01/02/2018            32         423           cloud
# 15  02/02/2018            35         156             Hot
# ...

# %%
#copying data to another csv file
df.to_csv("copy_weather_data.csv")

# %%
#creating dataset with lists
List=[["E01","SATHISH"],["E02","KARAN"],["E03","AKHIL"],["E04","SHREENATH"],["E05","SANTHOSH"],["E06","SAJITH"],["E07","SIVANT"]]
AI = pd.DataFrame(List,index=["a","b","c","d","e","f","g"],columns=["ID","NAME"])

# %%
with pd.ExcelWriter("sriher.xlsx")as data:
    AI.to_excel(data,sheet_name = "AI")

# %%
data1 = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-5a18e7c24f4a> in <module>
# ----> 1 data1 = pd.DataFrame(data)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466                                    dtype=values.dtype, copy=False)
#     467             else:
# --> 468                 raise ValueError('DataFrame constructor not properly called!')
#     469
#     470         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
import numpy as np
import pandas as pd
df = pd.DataFrame(np.random.randint(0,100,size=(10, 4)), columns=list('ABCD'))

# %%
df
# Out:
#     A   B   C   D
# 0   0  67  77  97
# 1   6  30  63  71
# 2  58  53  46  41
# 3  22  97  44   2
# 4  99  29  77  98
# 5  30  68  40  88
# 6  80  45  57  70
# 7  18  53  10  25
# 8   7  45  27  84
# 9  20  58  68   3

# %%
df.append({'A':5, 'B':56,"C":45,"D":123 }, ignore_index=True)
# Out:
#      A   B   C    D
# 0    0  67  77   97
# 1    6  30  63   71
# 2   58  53  46   41
# 3   22  97  44    2
# 4   99  29  77   98
# 5   30  68  40   88
# 6   80  45  57   70
# 7   18  53  10   25
# 8    7  45  27   84
# 9   20  58  68    3
# 10   5  56  45  123
