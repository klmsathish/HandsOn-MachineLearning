# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # SF Salaries Exercise
#
# Welcome to a quick exercise for you to practice your pandas skills! We will be using the [SF Salaries Dataset](https://www.kaggle.com/kaggle/sf-salaries) from Kaggle! Just follow along and complete the tasks outlined in bold below. The tasks will get harder and harder as you go along.

# %% [markdown]
# ** Import pandas as pd.**

# %%
import pandas as pd

# %% [markdown]
# ** Read Salaries.csv as a dataframe called sal.**

# %%
sal = pd.read_csv("Salaries.csv")

# %%
sal.shape
# Out:
# (148654, 13)

# %% [markdown]
# ** Check the head of the DataFrame. **

# %%
sal.head(5000)
# Out:
#         Id          EmployeeName  \
# 0        1        NATHANIEL FORD
# 1        2          GARY JIMENEZ
# 2        3        ALBERT PARDINI
# 3        4     CHRISTOPHER CHONG
# 4        5       PATRICK GARDNER
# 5        6        DAVID SULLIVAN
# 6        7             ALSON LEE
# 7        8         DAVID KUSHNER
# 8        9        MICHAEL MORRIS
# 9       10    JOANNE HAYES-WHITE
# 10      11         ARTHUR KENNEY
# 11      12      PATRICIA JACKSON
# 12      13     EDWARD HARRINGTON
# 13      14           JOHN MARTIN
# 14      15        DAVID FRANKLIN
# 15      16       RICHARD CORRIEA
# 16      17              AMY HART
# 17      18        SEBASTIAN WONG
# 18      19            MARTY ROSS
# 19      20         ELLEN MOFFATT
# 20      21            VENUS AZAR
# 21      22          JUDY MELINEK
# 22      23         GEORGE GARCIA
# 23      24         VICTOR WYRSCH
# 24      25       JOSEPH DRISCOLL
# 25      26          GREGORY SUHR
# 26      27           JOHN HANLEY
# 27      28        RAYMOND GUZMAN
# 28      29        DENISE SCHMITT
# 29      30         MONICA FIELDS
# ...    ...                   ...
# 4970  4971         MICHAEL HAUCK
# 4971  4972               MING HU
# 4972  4973       NICHOLAS SUSLOW
# 4973  4974  ROWENA SORIBEN-NOZIK
# 4974  4975          LARRY ABELLA
# 4975  4976            KIM HARMON
# 4976  4977           ALBERT WONG
# 4977  4978           ELISEO RUIZ
# 4978  4979         NELDA MALILAY
# 4979  4980       ALINE ARMSTRONG
# 4980  4981          LAWRENCE JEW
# 4981  4982      RICHARD MERCURIO
# 4982  4983       NESTOR BALINTEC
# 4983  4984         CHERYL MARTIN
# 4984  4985         CAROL SCATENA
# 4985  4986         JOSSIE ALEGRE
# 4986  4987    WILLIAM BRUNICARDI
# 4987  4988         BONITA SEAMAN
# 4988  4989      EVELYN ONDERDONK
# 4989  4990     SERGIO CONCEPCION
# 4990  4991     EDGAR COVARRUBIAS
# 4991  4992           DANA NELSON
# 4992  4993         PAULA ORDONEZ
# 4993  4994          JAMES BRYANT
# 4994  4995     RONALD MCGOLDRICK
# 4995  4996         SHIRAH WEXLER
# 4996  4997         MARIE DE VERA
# 4997  4998           RUANN NIEVA
# 4998  4999       STEPHANIE WARGO
# 4999  5000           REX LAVILLA
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# 5                            ASSISTANT DEPUTY CHIEF II  118602.00
# 6                   BATTALION CHIEF, (FIRE DEPARTMENT)   92492.01
# 7                       DEPUTY DIRECTOR OF INVESTMENTS  256576.96
# 8                   BATTALION CHIEF, (FIRE DEPARTMENT)  176932.64
# 9               CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  285262.00
# 10    ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  194999.39
# 11                     CAPTAIN III (POLICE DEPARTMENT)   99722.00
# 12                         EXECUTIVE CONTRACT EMPLOYEE  294580.02
# 13                                   DEPARTMENT HEAD V  271329.03
# 14                  BATTALION CHIEF, (FIRE DEPARTMENT)  174872.64
# 15                  COMMANDER III, (POLICE DEPARTMENT)  198778.01
# 16                                   DEPARTMENT HEAD V  268604.57
# 17               CAPTAIN, EMERGENCYCY MEDICAL SERVICES  140546.87
# 18                  BATTALION CHIEF, (FIRE DEPARTMENT)  168692.63
# 19                          ASSISTANT MEDICAL EXAMINER  257510.59
# 20                          ASSISTANT MEDICAL EXAMINER  257510.48
# 21                          ASSISTANT MEDICAL EXAMINER  257510.44
# 22                           CAPTAIN, FIRE SUPPRESSION  140546.88
# 23                  BATTALION CHIEF, (FIRE DEPARTMENT)  168692.63
# 24                           CAPTAIN, FIRE SUPPRESSION  140546.86
# 25                                     CHIEF OF POLICE  256470.41
# 26                           CAPTAIN, FIRE SUPPRESSION   92080.80
# 27                  BATTALION CHIEF, (FIRE DEPARTMENT)  168692.59
# 28                DEPUTY CHIEF III (POLICE DEPARTMENT)  261717.60
# 29        DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  246225.60
# ...                                                ...        ...
# 4970                           SENIOR RADIO TECHNICIAN  105042.93
# 4971                                  REGISTERED NURSE  119496.00
# 4972                                 POLICE OFFICER II  104613.42
# 4973                                  REGISTERED NURSE  123240.08
# 4974                                       FIREFIGHTER  105934.66
# 4975            MANAGER, UNIFIED FAMILY COURT SERVICES  122009.29
# 4976                                          ENGINEER  124293.29
# 4977                                    DEPUTY SHERIFF   86506.01
# 4978                               PUBLIC HEALTH NURSE  119496.03
# 4979                               PUBLIC HEALTH NURSE  119496.00
# 4980                                       FIREFIGHTER  105934.70
# 4981                      UTILITY PLUMBER SUPERVISOR I  102662.30
# 4982                         TRANSIT POWER LINE WORKER   92861.50
# 4983                         DIRECTOR, HUMAN RESOURCES  124332.41
# 4984                                POLICE OFFICER III  112441.82
# 4985                                        MANAGER II  112705.49
# 4986                                 POLICE OFFICER II  110223.08
# 4987                                        MANAGER II  118526.38
# 4988                                          ENGINEER  120937.03
# 4989                   TRANSIT POWER LINE SUPERVISOR I   99485.00
# 4990                                       FIREFIGHTER  105243.06
# 4991                                  REGISTERED NURSE  119675.52
# 4992                                  REGISTERED NURSE  104724.18
# 4993                  STATION AGENT, MUNICIPAL RAILWAY   72907.49
# 4994                                  POLICE OFFICER I   94105.70
# 4995                                     SPECIAL NURSE  114098.92
# 4996                                        MANAGER II  114237.22
# 4997                                  REGISTERED NURSE   99603.34
# 4998                         ATTORNEY (CIVIL/CRIMINAL)  124234.22
# 4999                                  REGISTERED NURSE  102057.22
#
#       OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  \
# 0            0.00  400184.25       NaN  567595.43         567595.43  2011
# 1       245131.88  137811.38       NaN  538909.28         538909.28  2011
# 2       106088.18   16452.60       NaN  335279.91         335279.91  2011
# 3        56120.71  198306.90       NaN  332343.61         332343.61  2011
# 
# 4994      7421.72   22712.64       NaN  124240.06         124240.06  2011
# 4995      4499.67    5638.94       NaN  124237.53         124237.53  2011
# 4996         0.00   10000.00       NaN  124237.22         124237.22  2011
# 4997     10215.45   14416.45       NaN  124235.24         124235.24  2011
# 4998         0.00       0.00       NaN  124234.22         124234.22  2011
# 4999      5710.17   16462.26       NaN  124229.65         124229.65  2011
#
#       Notes         Agency  Status
# 0       NaN  San Francisco     NaN
# 1       NaN  San Francisco     NaN
# 2       NaN  San Francisco     NaN
# 3       NaN  San Francisco     NaN
# 4       NaN  San Francisco     NaN
# 5       NaN  San Francisco     NaN
# 6       NaN  San Francisco     NaN
# 7       NaN  San Francisco     NaN
# 8       NaN  San Francisco     NaN
# 9       NaN  San Francisco     NaN
# 10      NaN  San Francisco     NaN
# 11      NaN  San Francisco     NaN
# 12      NaN  San Francisco     NaN
# 13      NaN  San Francisco     NaN
# 14      NaN  San Francisco     NaN
# 15      NaN  San Francisco     NaN
# 16      NaN  San Francisco     NaN
# 17      NaN  San Francisco     NaN
# 18      NaN  San Francisco     NaN
# 19      NaN  San Francisco     NaN
# 20      NaN  San Francisco     NaN
# 21      NaN  San Francisco     NaN
# 22      NaN  San Francisco     NaN
# 23      NaN  San Francisco     NaN
# 24      NaN  San Francisco     NaN
# 25      NaN  San Francisco     NaN
# 26      NaN  San Francisco     NaN
# 27      NaN  San Francisco     NaN
# 28      NaN  San Francisco     NaN
# 29      NaN  San Francisco     NaN
# ...     ...            ...     ...
# 4970    NaN  San Francisco     NaN
# 4971    NaN  San Francisco     NaN
# 4972    NaN  San Francisco     NaN
# 4973    NaN  San Francisco     NaN
# 4974    NaN  San Francisco     NaN
# 4975    NaN  San Francisco     NaN
# 4976    NaN  San Francisco     NaN
# 4977    NaN  San Francisco     NaN
# 4978    NaN  San Francisco     NaN
# 4979    NaN  San Francisco     NaN
# 4980    NaN  San Francisco     NaN
# 4981    NaN  San Francisco     NaN
# 4982    NaN  San Francisco     NaN
# 4983    NaN  San Francisco     NaN
# 4984    NaN  San Francisco     NaN
# 4985    NaN  San Francisco     NaN
# 4986    NaN  San Francisco     NaN
# 4987    NaN  San Francisco     NaN
# 4988    NaN  San Francisco     NaN
# 4989    NaN  San Francisco     NaN
# 4990    NaN  San Francisco     NaN
# 4991    NaN  San Francisco     NaN
# 4992    NaN  San Francisco     NaN
# 4993    NaN  San Francisco     NaN
# 4994    NaN  San Francisco     NaN
# 4995    NaN  San Francisco     NaN
# 4996    NaN  San Francisco     NaN
# 4997    NaN  San Francisco     NaN
# 4998    NaN  San Francisco     NaN
# 4999    NaN  San Francisco     NaN
#
# [5000 rows x 13 columns]

# %% [markdown]
# ** Use the .info() method to find out how many entries there are.**

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
# Id                  148654 non-null int64
# EmployeeName        148654 non-null object
# JobTitle            148654 non-null object
# BasePay             148045 non-null float64
# OvertimePay         148650 non-null float64
# OtherPay            148650 non-null float64
# Benefits            112491 non-null float64
# TotalPay            148654 non-null float64
# TotalPayBenefits    148654 non-null float64
# Year                148654 non-null int64
# Notes               0 non-null float64
# Agency              148654 non-null object
# Status              0 non-null float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %% [markdown]
# **What is the average BasePay ?**

# %%
sal["BasePay"].mean()
# Out:
# 66325.44884050643

# %% [markdown]
# ** What is the highest amount of OvertimePay in the dataset ? **

# %%
sal["OvertimePay"].max()
# Out:
# 245131.88

# %% [markdown]
# ** What is the job title of  JOSEPH DRISCOLL ? Note: Use all caps, otherwise you may get an answer that doesn't match up (there is also a lowercase Joseph Driscoll). **

# %%
joseph_driscoll = sal[sal['EmployeeName'] == 'JOSEPH DRISCOLL']
joseph_driscoll['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %% [markdown]
# ** How much does JOSEPH DRISCOLL make (including benefits)? **

# %%
joseph_driscoll['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# ** What is the name of highest paid person (including benefits)?**

# %%
sal[sal['TotalPay']==sal['TotalPay'].max()]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %% [markdown]
# ** What is the name of lowest paid person (including benefits)? Do you notice something strange about how much he or she is paid?**

# %%
sal[sal['TotalPay']==sal['TotalPay'].min()]
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653   -618.13       0.0   -618.13           -618.13  2014    NaN
#
#                Agency  Status
# 148653  San Francisco     NaN

# %% [markdown]
# ** What was the average (mean) BasePay of all employees per year? (2011-2014) ? **

# %%
sal.groupby('Year').mean()['BasePay']
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# ** How many unique job titles are there? **

# %%
sal['JobTitle'].nunique()
# Out:
# 2159

# %% [markdown]
# ** What are the top 5 most common jobs? **

# %%
sal['JobTitle'].value_counts().head(5)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %% [markdown]
# ** How many Job Titles were represented by only one person in 2013? (e.g. Job Titles with only one occurence in 2013?) **

# %%
sum(sal[sal['Year']==2013]['JobTitle'].value_counts()==1)
# Out:
# 202

# %% [markdown]
# ** How many people have the word Chief in their job title? (This is pretty tricky) **

# %%
def chief_string(title):
    if 'chief' in title.lower().split():
        return 1
    else:
        return 0

# %%
sum(sal['JobTitle'].apply( lambda x:chief_string(x)))
# Out:
# 477

# %% [markdown]
# ** Bonus: Is there a correlation between length of the Job Title string and Salary? **

# %%
sal['title_len'] = sal['JobTitle'].apply(len)

# %%
sal[['TotalPayBenefits', 'title_len']].corr()
# Out:
#                   TotalPayBenefits  title_len
# TotalPayBenefits          1.000000  -0.036878
# title_len                -0.036878   1.000000

# %% [markdown]
# # Great Job!
