# %%
import numpy as np
import pandas as pd
import seaborn as sb

# %%
df1 = pd.read_csv("df1",index_col = 0)

# %%
df2 = pd.read_csv("df2")

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1["A"].plot.hist()

# %%
df1.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001AAE215A198>,
# ...
#       dtype=object)

# %%
df1["A"].hist()

# %%
df2.plot.area(alpha= 0.5)

# %%
df2.plot.bar()

# %%
df1["A"].plot.bar()

# %%
df2.plot.bar(stacked=True)

# %%
df1.plot.hist(bins=10)

# %%
df1.plot.line(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001AAE5105208>,
# ...
#       dtype=object)

# %%
df1.plot.scatter(x= "A",y="B",c= "C",cmap = "viridis",s = df1["C"]*100)
# Out:
# C:\Users\SATHISH\Anaconda3\lib\site-packages\matplotlib\collections.py:874: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df1.plot.box()

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns = list("ab"))

# %%
df.plot.hexbin(x="a",y="b",gridsize=25)

# %%
df2["a"].plot.kde()

# %%
df2.plot.density()

# %%
import matplotlib.pyplot as pyp

# %%
np.random.seed(5)

# %%
x=np.arange(0.0,50,2)

# %%
y = x**1.3+np.random.rand(*x.shape)*30

# %%
s= np.random.rand(*x.shape)*800+500

# %%
pyp.scatter(x,y,s,c="g",alpha=0.9,marker = r'$\clubsuit$',label="Luck")
pyp.xlabel("Leprechauns")
pyp.ylabel("GOld")
pyp.legend(loc="upper left")

# %%
sb.catplot(x="A",y="B",data = df1)
